# %%
import requests
from requests import Response,JSONDecodeError,HTTPError
from pprint import pprint

url = 'https://data.ntpc.gov.tw/api/datasets/1b72abe8-8862-4130-aeb8-178c1240e6c4/json?page=0&size=1000'
try:
	r:Response = requests.request(method='GET',url=url)
	r.raise_for_status()
	data:list[dict] = r.json()
except HTTPError as e:
	print(f"web api目前有問題:{e}")
except JSONDecodeError as e:
	print(f"json格式有錯:{e}")
except Exception as e:
	print(f"發生錯誤:{e}")

# %%
pprint(data)
# Out:
# [{'build_case_unit': '自建案',
#   'bureau': '蘆洲分局',
#   'location': '四維路5號',
#   'unit': '更寮派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '蘆洲分局',
#   'location': '四維路5號',
#   'unit': '更寮派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '蘆洲分局',
#   'location': '四維路5號',
#   'unit': '更寮派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '蘆洲分局',
#   'location': '四維路5號',
#   'unit': '更寮派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '蘆洲分局',
#   'location': '四維路5號',
#   'unit': '更寮派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '蘆洲分局',
#   'location': '四維路5號',
#   'unit': '更寮派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '蘆洲分局',
#   'location': '永安南路2段環河大道口(鴨母港抽水站)',
#   'unit': '延平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '蘆洲分局',
#   'location': '永安南路2段環河大道口(鴨母港抽水站)',
#   'unit': '延平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '蘆洲分局',
#   'location': '永安南路2段環河大道口(鴨母港抽水站)',
#   'unit': '延平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '蘆洲分局',
#   'location': '永安南路2段環河大道口(鴨母港抽水站)',
#   'unit': '延平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '中正、忠愛街口',
#   'unit': '三多派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '中正、忠愛街口',
#   'unit': '三多派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '中正、忠愛街口',
#   'unit': '三多派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路一段270巷3弄2號',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路一段270巷3弄2號',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路一段270巷3弄2號',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路一段270巷3弄2號',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路一段270巷3弄2號',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路一段270巷3弄2號',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段23號往全家',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路2段369巷8號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路2段369巷8號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路2段369巷8號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '銘傳街34號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '銘傳街34號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '銘傳街34號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '銘傳街34號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '銘傳街34號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '銘傳街34號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '銘傳街34號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '長江路二段2號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '環河路、縣民大道',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '環河路、縣民大道',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '環河路、縣民大道',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '環河路、縣民大道',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民生路三段66號前台64下方分隔島',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民生路三段66號前台64下方分隔島',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民生路三段66號前台64下方分隔島',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民生路三段66號前台64下方分隔島',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民生路三段66號前台64下方分隔島',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '國光路67巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雨農路27巷2號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雨農路27巷2號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雨農路27巷2號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雨農路27巷2號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '陽明街90號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '陽明街90號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '陽明街90號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民生、長江路口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民生、長江路口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民生、長江路口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民生、長江路口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中正路413巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中正路413巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中正路413巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路二段505巷1號前往文化路二段路口全景',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路2段417巷口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '仁化街42巷口',
#   'unit': '文聖派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '仁化街42巷口',
#   'unit': '文聖派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雙十路二段167號旁號誌',
#   'unit': '文聖派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雙十路二段167號旁號誌',
#   'unit': '文聖派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路二段182巷3弄1號',
#   'unit': '文聖派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雙十路一段42號對面',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雙十路一段42號對面',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雙十路一段42號對面',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雙十路一段42號對面',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雙十路一段42號對面',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雙十路一段42號對面',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雙十路一段42號對面',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '莒光路63號',
#   'unit': '文聖派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '莒光路171巷',
#   'unit': '文聖派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '莒光路171巷',
#   'unit': '文聖派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '莒光路171巷',
#   'unit': '文聖派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '莒光路171巷',
#   'unit': '文聖派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '莒光路171巷',
#   'unit': '文聖派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '莒光路171巷',
#   'unit': '文聖派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '莒光路171巷',
#   'unit': '文聖派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路二段21號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路二段21號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路二段21號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '宏國路64巷口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '宏國路64巷口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '宏國路64巷口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '宏國路64巷口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '宏國路64巷口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '長江路2段280號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段274號',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段274號',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段274號',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段274號',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段286號前',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段503號',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段505巷口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '光復街202巷6號前',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路二段202-20號對面中央分隔島',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路二段202-20號對面中央分隔島',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路二段202-20號對面中央分隔島',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路二段204之3號對面中央分隔島',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路二段204之3號對面中央分隔島',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路二段204之3號對面中央分隔島',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路二段204之3號對面中央分隔島',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路二段204之3號對面中央分隔島',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '莒光路209號往180巷全景',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民翠華街口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民翠華街口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民翠華街口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民翠華街口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民翠華街口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民翠華街口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道三段247巷口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道三段247巷口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道三段247巷口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道三段247巷口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道3段193號',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道3段193號',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道3段193號',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道3段193號',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道3段193號',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路一段98號富山街口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路一段98號富山街口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路一段98號富山街口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道三段149號對面',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道三段149號對面',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道三段149號對面',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道三段149號對面',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路一段31巷口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路一段31巷口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '萬板莊敬路口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路一段159號',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路一段159號',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路一段159號',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路一段159號',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路一段159號',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路一段159號',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路一段159號',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山、新站路口東方',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山、新站路口東方',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山、新站路口東方',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山、新站路口東方',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段90巷、民享街東南方號誌桿',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段90巷、民享街東南方號誌桿',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段90巷、民享街東南方號誌桿',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段146號往148巷內',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '華翠橋上橋往台北快',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '華翠橋上橋往台北快',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '華翠橋上橋往台北快',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '華翠橋上橋往台北快',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路一段188巷30號前',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路一段188巷30號前',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路一段188巷30號前',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路一段188巷30號前',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '莊敬路168號',
#   'unit': '文聖派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '館前東路110號旁',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '館前東路110號旁',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路一段民權路東南方分隔島',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路一段民權路東南方分隔島',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路一段民權路東南方分隔島',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路一段民權路東南方分隔島',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '智樂路、新生街29巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '智樂路、新生街29巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '智樂路、新生街29巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '智樂路、新生街29巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新海路、裕民街口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新海路385巷34弄6號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新海路385巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新海路385巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新海路385巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新海路385巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新海路385巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新海路385巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新海路385巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新海路385巷口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '公館街252號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '公館街252號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '英士路179號前 (文德國小)',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '英士路179號前 (文德國小)',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新月一街(板橋國中後面)',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新月一街(板橋國中後面)',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '國光路189之3號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '國光路189之3號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '國光路189之3號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '國光路189之3號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '漢生西路1號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '漢生西路119巷口對面',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '漢生西路119巷口對面',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '金華街67號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '金華街67號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '金華街67號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '陽明街166號(靠四維路137巷)',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '陽明街166號(靠四維路137巷)',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '陽明街166號(靠四維路137巷)',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '陽明街166號(靠四維路137巷)',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雙十路三段66巷',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文德路陽明街口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文德路陽明街口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文德路陽明街口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文德路陽明街口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文德路陽明街口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文德路陽明街口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新埔一號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新埔一號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新埔一號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新埔一號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '新埔一號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路一段309號建華新城',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路一段309號建華新城',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路一段309號建華新城',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路一段309號建華新城',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '自由路51巷14弄口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '自由路51巷14弄口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '自由路51巷14弄口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '自由路51巷14弄口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '四維路128巷口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '四維路128巷口',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '四維路179號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '四維路179號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '四維路179號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '四維路179號',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '長江路一段四維路口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '長江路一段四維路口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '長江路一段四維路口',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '互助街48號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '互助街48號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '互助街48號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '互助街48號',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '大漢橋下',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '大漢橋下',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '大漢橋下',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '大漢橋下',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '大漢橋下',
#   'unit': '新海派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '重慶路290巷1號前',
#   'unit': '後埔派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '重慶路290巷1號前',
#   'unit': '後埔派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '重慶路290巷1號前',
#   'unit': '後埔派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '重慶路290巷1號前',
#   'unit': '後埔派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '重慶路290巷1號前',
#   'unit': '後埔派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '環河路475號前',
#   'unit': '大觀派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '環河路475號前',
#   'unit': '大觀派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '環河路475號前',
#   'unit': '大觀派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '環河路475號前',
#   'unit': '大觀派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '府中路區公所前',
#   'unit': '板橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '府中路區公所前',
#   'unit': '板橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '府中路區公所前',
#   'unit': '板橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '府中路區公所前',
#   'unit': '板橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '環河西路五段浮洲橋下東南方',
#   'unit': '大觀派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '環河西路五段浮洲橋下東南方',
#   'unit': '大觀派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '華東路與縣民大道一段口北方',
#   'unit': '信義派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '華東路與縣民大道一段口北方',
#   'unit': '信義派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '順風路26號前',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '順風路26號前',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '順風路26號前',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '順風路26號前',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '福仁街54號前',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '福仁街54號前',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '福仁街54號前',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '福仁街54號前',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '福祥街55號',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '福祥街55號',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '福祥街55號',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '中華路1段1號分隔島',
#   'unit': '廣福派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '學士路35號對面',
#   'unit': '清水派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '學士路35號對面',
#   'unit': '清水派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '學士路35號對面',
#   'unit': '清水派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '明德路二段與裕生路口',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '明德路二段與裕生路口',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '明德路二段與裕生路口',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '中央路1段69巷口',
#   'unit': '廣福派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '中央路1段69巷口',
#   'unit': '廣福派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '亞洲路66號前',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '亞洲路66號前',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '亞洲路66號前',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '亞洲路66號前',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '亞洲路66號前',
#   'unit': '土城派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '中央路一段116號前',
#   'unit': '廣福派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '中央路一段116號前',
#   'unit': '廣福派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '土城分局',
#   'location': '中央路一段116號前',
#   'unit': '廣福派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '浮洲橋下橋處第1支電桿',
#   'unit': '沙崙派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '溪崑國中大門左邊路燈122262號',
#   'unit': '沙崙派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '溪崑國中對面路燈122258號',
#   'unit': '沙崙派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '大觀路二段136號旁（號誌桿）',
#   'unit': '大觀派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '實踐路126號前號誌桿',
#   'unit': '後埔派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '文化路一段211號前（路燈）',
#   'unit': '板橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '環河路與南雅西路二段301巷41弄口（路燈：211561）',
#   'unit': '板橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '民權路與公館街口（民權路192號前路燈：208021）',
#   'unit': '板橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '中正路80巷與大智街口（號誌桿）',
#   'unit': '板橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '中正路與民權路口（中正路154號前路燈：023026）',
#   'unit': '板橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '北門街61號旁',
#   'unit': '板橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '西門街與光華街口（西門街18-2前路燈：014046）',
#   'unit': '板橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '南雅南路一段77號前',
#   'unit': '板橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '四川路二段140巷20號旁（路燈：108221）',
#   'unit': '信義派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '廣權路103號對面（路燈：103119）',
#   'unit': '信義派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '板橋分局',
#   'location': '廣權路與廣和街口（廣權路41號對面路燈：102009）',
#   'unit': '信義派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路1段156-1號前（路燈：203245）',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路1段158巷口（路燈：203244）',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路1段158巷口（路燈：203244）',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路1段160-5號（路燈：203246）',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路2段175號前（路燈）',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段223號前（路燈）',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段223號前（路燈）',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路2段241號前（路燈）',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民族路與中山路1段50巷口（路燈：088038）',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民權路45號旁（行人號誌桿）',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民權路與縣民大道（路燈：201201）',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民權路與縣民大道（中央分隔島路燈）',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民生路長安街口35號前號誌',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民生路長安街口、民生路三民路口號誌',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民生路長安街口(路燈：205010)',
#   'unit': '海山派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道三段與翠華街往板橋(反照)',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '縣民大道三段翠華街口往北市（號誌桿）',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路2段251號照往245巷口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段361號前 (路燈：004049)',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路2段260號前(路名標示桿)',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '三民路二段7號前(路燈',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路2段284號前(路燈)',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '永豐街與三民路1段102號口(路燈：079091)',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路2段507號照往505巷口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '中山路二段543號前(路燈：203194)',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '莒光路211號對面（中央分隔島號誌桿）',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '莒光路211號前（路燈：078004）',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '華翠大橋下橋往板橋(路名標示桿)',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '華翠大橋下橋往板橋(路名標示桿)',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '民生路二段、縣民大道三段口號誌桿',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '萬板路312巷口往北市（號誌桿）',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '萬板路328號照往312巷口',
#   'unit': '埔墘派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路2段161號前（路燈：202203）',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '文化路2段149號前（路燈：202201）',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '雙十路3段32號對面（中央分隔島路燈：206034）',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '長江路3段149-3號前（路燈：050106）',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '下華江橋往長江路',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '海山分局',
#   'location': '上華江橋匝道（中央分隔島路燈：202078）',
#   'unit': '江翠派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路4段88號對面新闢堤頂道路',
#   'unit': '得和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路4段88號對面新闢堤頂道路',
#   'unit': '得和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路4段88號對面新闢堤頂道路',
#   'unit': '得和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路4段88號對面新闢堤頂道路',
#   'unit': '得和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路4段88號對面新闢堤頂道路',
#   'unit': '得和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路4段88號對面新闢堤頂道路',
#   'unit': '得和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '成功路二段103號號誌桿',
#   'unit': '得和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '成功路二段103號號誌桿',
#   'unit': '得和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '成功路二段103號路燈(108383)',
#   'unit': '得和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '中正路154號路燈(109081)',
#   'unit': '得和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '中正路與民有街',
#   'unit': '得和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '中正路與民有街',
#   'unit': '得和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路二段永福水門路口路燈(167361)',
#   'unit': '中正橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路二段永福水門路口號誌桿',
#   'unit': '中正橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路二段永福水門路口號誌桿',
#   'unit': '中正橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路二段永福水門路口號誌桿',
#   'unit': '中正橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路二段永福水門路口號誌桿',
#   'unit': '中正橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路二段永福水門路口號誌桿',
#   'unit': '中正橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '警光街40號旁路燈',
#   'unit': '中正橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '中正路666巷50號路燈(103080)',
#   'unit': '中正橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '中正路666巷40號',
#   'unit': '中正橋派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '保生仁愛路路燈(100158)',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '仁愛路295號號誌桿',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '保生路64號路燈(100274)',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '保生仁愛路號誌桿',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段177號(消防隊旁)路燈(100170)',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段177號(消防隊旁)路燈(100171)',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段177號(消防隊旁)路燈(10071)',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段177之1號對面路燈',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段177之1號對面路燈',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段177之1號對面路燈',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段249號前號誌桿',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段249號前號誌桿',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段249號前號誌桿',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段249號前號誌桿',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段249號前號誌桿',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段249號前號誌桿',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段249號前號誌桿',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段249號前號誌桿',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河西路二段249號前路燈',
#   'unit': '新生派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '福和路222號前路燈(103004)',
#   'unit': '秀朗派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '福和路217號前號誌桿橫桿上',
#   'unit': '秀朗派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '福和路217號前號誌桿橫桿上',
#   'unit': '秀朗派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '福和橋上入轄處往新北永和',
#   'unit': '秀朗派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路3段42號對面',
#   'unit': '秀朗派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '福和橋上入轄處往台北',
#   'unit': '秀朗派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路3段42號對面',
#   'unit': '秀朗派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路3段42號對面',
#   'unit': '秀朗派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '環河東路3段42號對面',
#   'unit': '秀朗派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '永利路332巷7號對面路燈(108167)',
#   'unit': '秀朗派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '永利路163號對面路燈(108168)',
#   'unit': '秀朗派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '永利路173號路燈(108117)',
#   'unit': '秀朗派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '永和路一段2號號誌桿',
#   'unit': '永和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '永和路一段117號號誌桿',
#   'unit': '永和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '永和路一段117號號誌桿',
#   'unit': '永和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '永和路一段117號號誌桿',
#   'unit': '永和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '永和路一段116號號誌桿',
#   'unit': '永和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '永和路一段116號號誌桿',
#   'unit': '永和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '永和分局',
#   'location': '永和路一段97號燈桿',
#   'unit': '永和派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '永貞路264號號誌桿',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '中和路503號前（號誌桿）',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '中和路493號前號誌桿',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '景安保建路口號誌桿',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '景安保建路口（號誌橫桿上）',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '保建路2巷2號附壁',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '保建路44巷2號（路燈：41541）',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '保建路61巷1號（路燈：45040）',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '保建路61巷1號(路燈45040)',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '新興街15巷22號(路燈46064)',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '新興街17巷29號(路燈4606１)',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '新興街8巷1號(路燈46045)',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '景新273巷12號（路燈：55021）',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '景新273巷18號（路燈：55022）',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '景新273巷口牌桿',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '景新街285巷15號（路燈：55031）',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '景新285巷11號（路燈：55032）',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '景新295巷2號（路燈：55039）',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '景新街295巷10號（路燈：55040）',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '保健路46巷26弄10號(路燈41516）',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '保健路46巷33號外路燈（41528)',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '保健路46巷39弄11號(路燈41510)',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '景安路79巷37弄8號（路燈：41086）',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '景安路79巷37弄2號(路燈41092',
#   'unit': '安平派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '景新街479號鐵桿',
#   'unit': '南勢派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '景新街485號號誌桿',
#   'unit': '南勢派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '景新街510號前路燈（56530）',
#   'unit': '南勢派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '忠孝街105號（路燈57055)',
#   'unit': '南勢派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '忠孝街136號前（號誌桿）',
#   'unit': '南勢派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '中和分局',
#   'location': '忠孝街140號（號誌桿）',
#   'unit': '南勢派出所',
#   'year': '114'},
# ...
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '汐止分局',
#   'location': '樟樹一路129巷1號',
#   'unit': '社后派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '汐止分局',
#   'location': '樟樹一路129巷1號',
#   'unit': '社后派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '汐止分局',
#   'location': '樟樹一路152巷口',
#   'unit': '社后派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '汐止分局',
#   'location': '樟樹一路148號前',
#   'unit': '社后派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '汐止分局',
#   'location': '樟樹一路137巷(07109燈桿)',
#   'unit': '社后派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '汐止分局',
#   'location': '樟樹一路135巷2號前號誌',
#   'unit': '社后派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '汐止分局',
#   'location': '樟樹一路162號汐止區農會前號誌.',
#   'unit': '社后派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '汐止分局',
#   'location': '樟樹一
',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '大安路、俊英街口（路燈：52015）',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '大安路、俊英街口（號誌桿）',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '保安街二段47號號誌桿',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '保安街二段47號號誌桿',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '保安街二段69號號誌桿',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '武林國小前（路燈：55060）',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '復興路102號旁（號誌桿）',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '鎮前街、保安街1段（號誌桿）',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '鎮前街、保安街1段（路名標示桿）',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '復興路390巷20號(樹林公八停車場)路燈',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '復興路390巷20號(樹林公八停車場)路燈',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '樹新路127號路燈(228160)',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '樹新路127號路燈(228160)-02',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '保順街97號旁路燈',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '保順街97號旁路燈-02',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '水源街32巷口號誌桿',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '水源街32巷口號誌桿-02',
#   'unit': '樹林派出所',
#   'year': '114'},
#  {'build_case_unit': '自建案',
#   'bureau': '樹林分局',
#   'location': '水源街32巷口號誌桿-03',
#   'unit': '彭厝派出所',
#   'year': '114'}]

# %%
from pydantic import BaseModel, TypeAdapter

class CameraPosition(BaseModel):
    year:int
    bureau:str
    unit:str
    location:str
    
adapter = TypeAdapter(list[CameraPosition])
list_position:list[CameraPosition] = adapter.validate_python(data)

# %%
output_json_str:str = adapter.dump_json(list_position).decode()
output_json_str
# Out:
# '[{"year":114,"bureau":"蘆洲分局","unit":"更寮派出所","location":"四維路5號"},{"year":114,"bureau":"蘆洲分局","unit":"更寮派出所","location":"四維路5號"},{"year":114,"bureau":"蘆洲分局","unit":"更寮派出所","location":"四維路5號"},{"year":114,"bureau":"蘆洲分局","unit":"更寮派出所","location":"四維路5號"},{"year":114,"bureau":"蘆洲分局","unit":"更寮派出所","location":"四維路5號"},{"year":114,"bureau":"蘆洲分局","unit":"更寮派出所","location":"四維路5號"},{"year":114,"bureau":"蘆洲分局","unit":"延平派出所","location":"永安南路2段環河大道口(鴨母港抽水站)"},{"year":114,"bureau":"蘆洲分局","unit":"延平派出所","location":"永安南路2段環河大道口(鴨母港抽水站)"},{"year":114,"bureau":"蘆洲分局","unit":"延平派出所","location":"永安南路2段環河大道口(鴨母港抽水站)"},{"year":114,"bureau":"蘆洲分局","unit":"延平派出所","location":"永安南路2段環河大道口(鴨母港抽水站)"},{"year":114,"bureau":"樹林分局","unit":"三多派出所","location":"中正、忠愛街口"},{"year":114,"bureau":"樹林分局","unit":"三多派出所","location":"中正、忠愛街口"},{"year":114,"bureau":"樹林分局","unit":"三多派出所","location":"中正、忠愛街口"},{"year":114,"bureau":"海山分局","unit":"海山派出所","location":"文化路一段270巷3弄2號"},{"year":114,"bureau":"海山分局","unit":"海山派出所","location":"文化路一段270巷3弄2號"},{"year":114,"bureau":"海山分局","unit":"海山派出所","location":"文化路一段270巷3弄2號"},{"year":114,"bureau":"海山分局","unit":"海山派出所","location":"文化路一段270巷3弄2號"},{"year":114,"bureau":"海山分局","unit":"海山派出所","location":"文化路一段270巷3弄2號"},{"year":114,"bureau":"海山分局","unit":"海山派出所","location":"文化路一段270巷3弄2號"},{"year":114,"bureau":"海山分局","unit":"海山派出所","location":"中山路二段23號往全家"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"文化路2段369巷8號"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"文化路2段369巷8號"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"文化路2段369巷8號"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"銘傳街34號"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"銘傳街34號"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"銘傳街34號"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"銘傳街34號"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"銘傳街34號"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"銘傳街34號"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"銘傳街34號"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"長江路二段2號"},{"year":114,"bureau":"海山分局","unit":"埔墘派出所","location":"環河路、縣民大道"},{"year":114,"bureau":"海山分局","unit":"埔墘派出所","location":"環河路、縣民大道"},{"year":114,"bureau":"海山分局","unit":"埔墘派出所","location":"環河路、縣民大道"},{"year":114,"bureau":"海山分局","unit":"埔墘派出所","location":"環河路、縣民大道"},{"year":114,"bureau":"海山分局","unit":"海山派出所","location":"民生路三段66號前台64下方分隔島"},{"year":114,"bureau":"海山分局","unit":"海山派出所","location":"民生路三段66號前台64下方分隔島"},{"year":114,"bureau":"海山分局","unit":"海山派出所","location":"民生路三段66號前台64下方分隔島"},{"year":114,"bureau":"海山分局","unit":"海山派出所","location":"民生路三段66號前台64下方分隔島"},{"year":114,"bureau":"海山分局","unit":"海山派出所","location":"民生路三段66號前台64下方分隔島"},{"year":114,"bureau":"海山分局","unit":"新海派出所","location":"國光路67巷口"},{"year":114,"bureau":"海山分局","unit":"新海派出所","location":"雨農路27巷2號"},{"year":114,"bureau":"海山分局","unit":"新海派出所","location":"雨農路27巷2號"},{"year":114,"bureau":"海山分局","unit":"新海派出所","location":"雨農路27巷2號"},{"year":114,"bureau":"海山分局","unit":"新海派出所","location":"雨農路27巷2號"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"陽明街90號"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"陽明街90號"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"陽明街90號"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"民生、長江路口"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"民生、長江路口"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"民生、長江路口"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"民生、長江路口"},{"year":114,"bureau":"海山分局","unit":"新海派出所","location":"中正路413巷口"},{"year":114,"bureau":"海山分局","unit":"新海派出所","location":"中正路413巷口"},{"year":114,"bureau":"海山分局","unit":"新海派出所","location":"中正路413巷口"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"文化路二段505巷1號前往文化路二段路口全景"},{"year":114,"bureau":"海山分局","unit":"江翠派出所","location":"文化路2段417巷口"},{"year":114,"bureau":"海山分局","unit":"文聖派出所","location":"仁化街42巷口"},{"year":114,"bureau":"海山分局","unit":"文聖派出所","location":"仁化街42巷口"},{"year ...
