# %% [markdown]
# ## 訓練模型

# %% [markdown]
# ### 讀檔

# %%
# ------------------------------------
# 取得csv的絕對路徑
# ------------------------------------

import os
#current_dir = os.path.dirname(os.path.abspath(__file__))
current_dir:str = os.getcwd()
csv_path:str = os.path.join(current_dir, "Salary_Data2.csv")
print(csv_path)
# Out:
# /Users/roberthsu2003/Documents/GitHub/2026_07_03_python_ai_tvdi/backend/07_31/Salary_Data2.csv
