# %%
print("hello world")
# Out:
# hello world

# %%
import math

a:int = 3
b:int = 4
value:float = math.pow(a, 2) + math.pow(b,2)
value1:float = math.sqrt(value)
print(value1)
# Out:
# 25.0

# %%
[
    {'name':"robert",'age':30},
    {'name':"jenny",'age':25},
    {'name':"ken",'age':35}
]
# Out:
# [{'name': 'robert', 'age': 30},
#  {'name': 'jenny', 'age': 25},
#  {'name': 'ken', 'age': 35}]
