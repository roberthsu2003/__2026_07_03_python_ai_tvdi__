# %%
import yfinance as yf

# 抓取台積電 (2330.TW) 股票資料
tsmc = yf.Ticker("2330.TW")

# 取得最近 1 個月的日線資料
hist = tsmc.history(period="1mo")
print("=== 台積電 (2330.TW) 最近 1 個月股價 ===")
print(hist.tail(10))

# 取得股票基本資訊
info = tsmc.info
print("\n=== 股票基本資訊 ===")
print(f"公司名稱: {info.get('shortName', 'N/A')}")
print(f"目前股價: {info.get('currentPrice', 'N/A')}")
print(f"52週最高: {info.get('fiftyTwoWeekHigh', 'N/A')}")
print(f"52週最低: {info.get('fiftyTwoWeekLow', 'N/A')}")
print(f"市值: {info.get('marketCap', 'N/A')}")
# Out:
# === 台積電 (2330.TW) 最近 1 個月股價 ===
#                              Open    High     Low   Close    Volume  \
# Date
# 2026-07-08 00:00:00+08:00  2445.0  2465.0  2420.0  2465.0  23373702
# 2026-07-09 00:00:00+08:00  2450.0  2460.0  2415.0  2415.0  27134789
# 2026-07-10 00:00:00+08:00  2415.0  2415.0  2415.0  2415.0         0
# 2026-07-13 00:00:00+08:00  2460.0  2480.0  2440.0  2440.0  32938379
# 2026-07-14 00:00:00+08:00  2410.0  2430.0  2390.0  2420.0  35607811
# 2026-07-15 00:00:00+08:00  2425.0  2460.0  2415.0  2440.0  28532735
# 2026-07-16 00:00:00+08:00  2430.0  2470.0  2420.0  2470.0  27848158
# 2026-07-17 00:00:00+08:00  2375.0  2395.0  2290.0  2290.0  75253147
# 2026-07-20 00:00:00+08:00  2300.0  2345.0  2300.0  2320.0  45272691
# 2026-07-21 00:00:00+08:00  2350.0  2410.0  2345.0  2410.0  31271386
#
#                            Dividends  Stock Splits
# Date
# 2026-07-08 00:00:00+08:00        0.0           0.0
# 2026-07-09 00:00:00+08:00        0.0           0.0
# 2026-07-10 00:00:00+08:00        0.0           0.0
# 2026-07-13 00:00:00+08:00        0.0           0.0
# 2026-07-14 00:00:00+08:00        0.0           0.0
# 2026-07-15 00:00:00+08:00        0.0           0.0
# 2026-07-16 00:00:00+08:00        0.0           0.0
# 2026-07-17 00:00:00+08:00        0.0           0.0
# 2026-07-20 00:00:00+08:00        0.0           0.0
# 2026-07-21 00:00:00+08:00        0.0           0.0
#
# === 股票基本資訊 ===
# 公司名稱: TAIWAN SEMICONDUCTOR MANUFACTUR
# 目前股價: 2410.0
# 52週最高: 2535.0
# 52週最低: 1125.0
# 市值: 62497012842496
